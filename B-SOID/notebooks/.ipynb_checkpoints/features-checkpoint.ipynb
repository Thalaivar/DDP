# %%
import logging
logging.basicConfig(level=logging.INFO)

import sys
sys.path.insert(0, "D:/IIT/DDP/DDP/B-SOID/")
import random
import numpy as np
import seaborn as sns 

from BSOID.bsoid import *
from BSOID.preprocessing import *
from BSOID.features import *
from behavelet import wavelet_transform
# Out:
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\behavelet\morlet.py:26: UserWarning: CuPy was not found, so GPU functionality is unavailable. See https://github.com/cupy/cupy#installation for installation instructions
#   warnings.warn('CuPy was not found, so GPU functionality is unavailable. '

# %%
# %matplotlib notebook
def plot(X, **kwargs):
    plt.scatter(X[:,0], X[:,1], **kwargs)
    plt.show()

# %% [markdown]
# # Embedding for Visualization

# %%
def extract_feats(filtered_data, fps, stride_window):
    x_raw, y_raw = filtered_data['x'], filtered_data['y']
    assert x_raw.shape == y_raw.shape
    N, n_dpoints = x_raw.shape

#     win_len = np.int(np.round(0.05 / (1 / fps)) * 2 - 1) if stride_window  is None else stride_window // 2
    win_len = 3
    x, y = np.zeros_like(x_raw), np.zeros_like(y_raw)
    for i in range(n_dpoints):
        x[:,i] = smoothen_data(x_raw[:,i], win_len)
        y[:,i] = smoothen_data(y_raw[:,i], win_len)
    
#     disp = np.linalg.norm(np.array([x[1:,:] - x[0:N-1,:], y[1:,:] - y[0:N-1,:]]), axis=0)
    links = [np.array([x[:,i] - x[:,j], y[:,i] - y[:,j]]).T for i, j in combinations(range(n_dpoints), 2)]
    link_lens = np.vstack([np.linalg.norm(link, axis=1) for link in links]).T
    link_angles = np.vstack([np.arctan2(link[:,1], link[:,0]) for i, link in enumerate(links)]).T
    
    if stride_window > 1:
        link_lens = windowed_feats(link_lens, stride_window, mode="mean")
        link_angles = windowed_feats(link_angles, stride_window, mode="sum")
#         disp = windowed_feats(disp, stride_window, mode="sum")

    return np.hstack((link_angles, link_lens))

def subsample(data, num_points):
    N = data.shape[0]
    skipLength = np.floor(N / num_points).astype(int)
    if skipLength == 0:
        skipLength = 1
        numPoints = N
    firstFrame = N % num_points
    data = data[firstFrame:int(firstFrame + (num_points) * skipLength): skipLength]
    return data

# %%
bsoid = BSOID("../config/config.yaml")
fdata = bsoid.load_filtered_data()
# fdata = fdata[random.sample(list(fdata.keys()), 1)[0]]
fdata = fdata["C57BL/6NJ"]
feats = np.vstack(Parallel(n_jobs=-1)(delayed(extract_feats)(data, bsoid.fps, 1) for data in fdata))
del fdata
feats.shape
# Out:
#     Run ID       : dis
#  Save Location   : D:/IIT/DDP/data\dis/output
#       FPS        : 30
#  Min. Confidence : 0.3
#   Stride Window  : 333ms
# (540000, 56)

# %%
par_wav_trans = lambda x: subsample(wavelet_transform(x, n_freqs=25, fmax=15, fmin=1, fsample=30)[2], 25000)

def par_wav_trans(x, numPoints):
    print(x.shape)
    x = wavelet_transform(x, n_freqs=25, fmax=15, fmin=1, fsample=30)[2]
    return subsample(x, numPoints)
# wav = Parallel(n_jobs=-)(delayed(par_wav_trans)(feats[:,i], 25000) for i in range(feats.shape[1]))
par_wav_trans(feats[:,0], 25000)
wav.shape
# Out:
# (540000,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-bf1df93527ab> in <module>
#       6     return subsample(x, numPoints)
#       7 # wav = Parallel(n_jobs=-)(delayed(par_wav_trans)(feats[:,i], 25000) for i in range(feats.shape[1]))
# ----> 8 par_wav_trans(feats[:,0], 25000)
#       9 wav.shape
#
# <ipython-input-21-bf1df93527ab> in par_wav_trans(x, numPoints)
#       3 def par_wav_trans(x, numPoints):
#       4     print(x.shape)
# ----> 5     x = wavelet_transform(x, n_freqs=25, fmax=15, fmin=1, fsample=30)[2]
#       6     return subsample(x, numPoints)
#       7 # wav = Parallel(n_jobs=-)(delayed(par_wav_trans)(feats[:,i], 25000) for i in range(feats.shape[1]))
#
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\behavelet\morlet.py in wavelet_transform(X, n_freqs, fsample, fmin, fmax, prob, omega0, log_scale, n_jobs, gpu)
#     293         pool.close()
#     294     else:
# --> 295         convolved = list(map(_morlet_fft_convolution_parallel, feed_dicts))
#     296
#     297     X_new = np.concatenate(convolved, axis=1)
#
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\behavelet\morlet.py in _morlet_fft_convolution_parallel(feed_dict)
#     179
#     180 def _morlet_fft_convolution_parallel(feed_dict):
# --> 181     return _morlet_fft_convolution(**feed_dict)
#     182
#     183
#
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\behavelet\morlet.py in _morlet_fft_convolution(X, freqs, scales, dtime, omega0, gpu)
#     113         backend = np
#     114
# --> 115     n_samples = X.shape[0]
#     116     # n_freqs = freqs.shape[0]
#     117
#
# IndexError: tuple index out of range

# %%
from numba import njit
@njit(fastmath=True)
def KL(x, y):
    x, y = x / x.sum(), y / y.sum()
    logx, logy = np.log(x), np.log(y)
    logx[~np.isfinite(logx)] = 0
    logy[~np.isfinite(logy)] = 0
    
    D = np.sum(x * logx) - np.sum(x * logy)
    D /= np.log(2)
    return np.square(D)

# %%
# from openT
embed = umap.UMAP(n_components=25, n_neighbors=10, min_dist=0.0, metric=KL, verbose=True).fit_transform(wav)
assignments, _, soft_assignments, _ = cluster_with_hdbscan(embed, [0.4, 1.2, 9], bsoid.hdbscan_params)
# Out:
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\umap\umap_.py:1728: UserWarning: custom distance metric does not return gradient; inverse_transform will be unavailable. To enable using inverse_transform method method, define a distance function that returns a tuple of (distance [float], gradient [np.array])
#   "custom distance metric does not return gradient; inverse_transform will be unavailable. "
# UMAP(dens_frac=0.0, dens_lambda=0.0,
#      metric=CPUDispatcher(<function KL at 0x000001D766537D38>), min_dist=0.0,
#      n_components=25, n_neighbors=10, verbose=True)
# Construct fuzzy simplicial set
# Wed May 12 14:08:07 2021 Finding Nearest Neighbors
# Wed May 12 14:08:07 2021 Building RP forest with 13 trees
# Wed May 12 14:08:09 2021 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	Stopping threshold met -- exiting after 4 iterations
# Wed May 12 14:08:33 2021 Finished Nearest Neighbor Search
# Wed May 12 14:08:36 2021 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed May 12 14:09:36 2021 Finished embedding
# INFO:root:identified 21 clusters (max is 21) with min_sample_prop=0.4 and entropy_ratio=0.875
# INFO:root:identified 21 clusters (max is 21) with min_sample_prop=0.5 and entropy_ratio=0.875
# INFO:root:identified 21 clusters (max is 21) with min_sample_prop=0.6 and entropy_ratio=0.875
# INFO:root:identified 19 clusters (max is 21) with min_sample_prop=0.7 and entropy_ratio=0.889
# INFO:root:identified 17 clusters (max is 21) with min_sample_prop=0.8 and entropy_ratio=0.907
# INFO:root:identified 16 clusters (max is 21) with min_sample_prop=0.9 and entropy_ratio=0.917
# INFO:root:identified 16 clusters (max is 21) with min_sample_prop=1.0 and entropy_ratio=0.917
# INFO:root:identified 16 clusters (max is 21) with min_sample_prop=1.1 and entropy_ratio=0.917
# INFO:root:identified 16 clusters (max is 21) with min_sample_prop=1.2 and entropy_ratio=0.917

# %%
vis_embed = umap.UMAP(n_components=2, n_neighbors=10, min_dist=0.0, metric=KL).fit_transform(wav)
plot(vis_embed, c=soft_assignments, s=0.1, alpha=0.15)
# Out:
# D:\Applications\anaconda3\envs\ddp\lib\site-packages\umap\umap_.py:1728: UserWarning: custom distance metric does not return gradient; inverse_transform will be unavailable. To enable using inverse_transform method method, define a distance function that returns a tuple of (distance [float], gradient [np.array])
#   "custom distance metric does not return gradient; inverse_transform will be unavailable. "
# <img src="data:image/png;base64,..." width="640">
